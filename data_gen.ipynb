# %%
import csv
import json
import os
import re
from collections import Counter
from pathlib import Path
from urllib.error import HTTPError, URLError
from urllib.request import Request, urlopen

BASE_URL = "https://www.thebluealliance.com/api/v3"

# Inclusive year range to process.
START_YEAR = 2023
END_YEAR = 2026

# TBA event_type 99 is Offseason.
OFFSEASON_EVENT_TYPE = 99


def load_tba_key(env_path: str = ".env") -> str:
    key = os.getenv("TBA_KEY")
    if key:
        return key.strip()

    p = Path(env_path)
    if not p.exists():
        raise FileNotFoundError(f"Could not find {env_path} and TBA_KEY is not set in environment.")

    for line in p.read_text(encoding="utf-8").splitlines():
        line = line.strip()
        if not line or line.startswith("#"):
            continue
        if line.startswith("TBA_KEY="):
            value = line.split("=", 1)[1].strip().strip('"').strip("'")
            if value:
                return value

    raise ValueError("TBA_KEY was not found in .env")


def tba_get(path: str, key: str):
    url = f"{BASE_URL}{path}"
    headers = {
        "X-TBA-Auth-Key": key,
        "User-Agent": "cs2621-term-project/1.0 (+python)",
        "Accept": "application/json",
    }
    req = Request(url, headers=headers)
    try:
        with urlopen(req, timeout=30) as response:
            return json.loads(response.read().decode("utf-8"))
    except HTTPError as e:
        body = e.read().decode("utf-8", errors="replace")
        raise RuntimeError(f"HTTP error {e.code} for {url}: {body}") from e
    except URLError as e:
        raise RuntimeError(f"Network error for {url}: {e}") from e


def is_offseason_event(event_obj):
    event_type = event_obj.get("event_type")
    event_type_string = (event_obj.get("event_type_string") or "").strip().lower()
    return event_type == OFFSEASON_EVENT_TYPE or event_type_string == "offseason"


def parse_alliance_number(alliance_obj):
    number = alliance_obj.get("number")
    if isinstance(number, int):
        return number

    name = alliance_obj.get("name") or ""
    match = re.search(r"(\d+)", name)
    if match:
        return int(match.group(1))

    return None


def team_num(team_key):
    if isinstance(team_key, str):
        return team_key.replace("frc", "").strip()
    return team_key


def build_alliance_slots(alliances):
    slot_rows = []
    used_slots = set()

    for idx, alliance in enumerate(alliances, start=1):
        slot = parse_alliance_number(alliance)
        if slot is None or slot in used_slots:
            slot = idx
            while slot in used_slots:
                slot += 1
        used_slots.add(slot)

        picks = alliance.get("picks") or []
        slot_rows.append(
            {
                "slot": slot,
                "name": alliance.get("name"),
                "status": (alliance.get("status") or {}).get("status"),
                "picks": picks,
                "pick_set": set(picks),
            }
        )

    return slot_rows


def infer_winner_slot_from_matches(event_key, slot_rows, tba_key):
    matches = tba_get(f"/event/{event_key}/matches", tba_key)
    if not matches:
        return None

    playoff_matches = [m for m in matches if m.get("comp_level") in {"f", "sf", "qf", "ef"}]
    if not playoff_matches:
        return None

    # Prefer finals first; if unavailable, fall back to deepest available playoff level.
    for level in ["f", "sf", "qf", "ef"]:
        level_matches = [m for m in playoff_matches if m.get("comp_level") == level]
        if level_matches:
            playoff_matches = level_matches
            break

    wins_by_slot = Counter()
    for match in playoff_matches:
        winner_side = match.get("winning_alliance")
        if winner_side not in {"red", "blue"}:
            continue

        side_info = (match.get("alliances") or {}).get(winner_side) or {}
        winner_team_keys = set(side_info.get("team_keys") or [])
        if not winner_team_keys:
            continue

        best_slot = None
        best_overlap = -1
        for slot_row in slot_rows:
            overlap = len(winner_team_keys & slot_row["pick_set"])
            if overlap > best_overlap:
                best_overlap = overlap
                best_slot = slot_row["slot"]

        if best_slot is not None and best_overlap > 0:
            wins_by_slot[best_slot] += 1

    if not wins_by_slot:
        return None

    return wins_by_slot.most_common(1)[0][0]


def get_winning_alliance_number(event_key, slot_rows, tba_key):
    for slot_row in slot_rows:
        if slot_row["status"] == "won":
            return slot_row["slot"]

    return infer_winner_slot_from_matches(event_key, slot_rows, tba_key)


def normalize_event_row(event_key, year, alliances, tba_key):
    slot_rows = build_alliance_slots(alliances)

    row = {
        "year": year,
        "event_key": event_key,
        "winning_alliance": get_winning_alliance_number(event_key, slot_rows, tba_key),
    }

    for slot_row in sorted(slot_rows, key=lambda r: r["slot"]):
        picks = slot_row["picks"]
        slot = slot_row["slot"]
        row[f"alliance_{slot}_captain"] = team_num(picks[0]) if len(picks) > 0 else None
        row[f"alliance_{slot}_pick_2"] = team_num(picks[1]) if len(picks) > 1 else None
        row[f"alliance_{slot}_pick_3"] = team_num(picks[2]) if len(picks) > 2 else None

    return row


def fetch_event_rows_for_year(year: int, tba_key: str):
    events = tba_get(f"/events/{year}", tba_key)
    rows = []

    for event in events:
        if is_offseason_event(event):
            continue

        event_key = event.get("key")
        if not event_key:
            continue

        alliances = tba_get(f"/event/{event_key}/alliances", tba_key)
        if not alliances:
            continue

        rows.append(normalize_event_row(event_key=event_key, year=year, alliances=alliances, tba_key=tba_key))

    return rows


def fetch_event_rows_for_years(start_year: int, end_year: int, tba_key: str):
    all_rows = []

    for year in range(start_year, end_year + 1):
        year_rows = fetch_event_rows_for_year(year, tba_key)
        all_rows.extend(year_rows)
        print(f"{year}: {len(year_rows)} event rows")

    return all_rows


def build_fieldnames(rows):
    fieldnames = ["year", "event_key", "winning_alliance"]

    alliance_nums = set()
    for row in rows:
        for key in row.keys():
            match = re.match(r"alliance_(\d+)_(captain|pick_2|pick_3)$", key)
            if match:
                alliance_nums.add(int(match.group(1)))

    for n in sorted(alliance_nums):
        fieldnames.append(f"alliance_{n}_captain")
        fieldnames.append(f"alliance_{n}_pick_2")
        fieldnames.append(f"alliance_{n}_pick_3")

    return fieldnames


def write_csv(rows, output_path="playoff_alliances_with_winners.csv"):
    fieldnames = build_fieldnames(rows)

    with open(output_path, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)


def main():
    tba_key = load_tba_key(".env")
    rows = fetch_event_rows_for_years(START_YEAR, END_YEAR, tba_key)
    write_csv(rows)

    missing_winners = sum(1 for row in rows if row.get("winning_alliance") is None)
    print(f"Wrote {len(rows)} event rows to playoff_alliances_with_winners.csv")
    print(f"Events with missing winner after fallback: {missing_winners}")
    if rows:
        print("Sample row:")
        print(rows[0])


main()
# Out:
# 2023: 185 event rows
# 2024: 191 event rows
# 2025: 204 event rows
# 2026: 202 event rows
# Wrote 782 event rows to playoff_alliances_with_winners.csv
# Events with missing winner after fallback: 0
# Sample row:
# {'year': 2023, 'event_key': '2023alhu', 'winning_alliance': 1, 'alliance_1_captain': '3937', 'alliance_1_pick_2': '4499', 'alliance_1_pick_3': '7072', 'alliance_2_captain': '1466', 'alliance_2_pick_2': '179', 'alliance_2_pick_3': '2556', 'alliance_3_captain': '3630', 'alliance_3_pick_2': '2992', 'alliance_3_pick_3': '6517', 'alliance_4_captain': '1038', 'alliance_4_pick_2': '8044', 'alliance_4_pick_3': '1747', 'alliance_5_captain': '6823', 'alliance_5_pick_2': '5472', 'alliance_5_pick_3': '5410', 'alliance_6_captain': '2438', 'alliance_6_pick_2': '7565', 'alliance_6_pick_3': '4576', 'alliance_7_captain': '3959', 'alliance_7_pick_2': '3284', 'alliance_7_pick_3': '5002', 'alliance_8_captain': '1622', 'alliance_8_pick_2': '233', 'alliance_8_pick_3': '3616'}

# %%
import re
import threading
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

import pandas as pd
import statbotics

INPUT_CSV = "playoff_alliances_with_winners.csv"
OUTPUT_CSV = "playoff_alliances_with_team_statbotics.csv"

# Tune based on API/network limits.
MAX_WORKERS = 12
MAX_RETRIES = 3
BACKOFF_SECONDS = 0.5

df = pd.read_csv(INPUT_CSV)

# Identify only the original team columns once.
team_col_pattern = re.compile(r"^alliance_\d+_(captain|pick_2|pick_3)$")
team_cols = [c for c in df.columns if team_col_pattern.match(c)]

# Add enrichment columns once.
for col in team_cols:
    df[f"{col}_epa"] = pd.NA
    df[f"{col}_epa_norm"] = pd.NA
    df[f"{col}_rp_1"] = pd.NA
    df[f"{col}_rp_2"] = pd.NA

# Build tasks and de-duplicate requests so each team/event is fetched once.
tasks = []
unique_requests = set()

for row_idx, row in df[["event_key", *team_cols]].iterrows():
    event_key = row["event_key"]
    for col in team_cols:
        team_value = row[col]
        if pd.isna(team_value):
            continue
        try:
            team_num = int(team_value)
        except (TypeError, ValueError):
            continue

        task = (row_idx, col, team_num, event_key)
        tasks.append(task)
        unique_requests.add((team_num, event_key))

print(f"Rows: {len(df)}")
print(f"Team assignments to fill: {len(tasks)}")
print(f"Unique API requests: {len(unique_requests)}")

thread_local = threading.local()


def get_client():
    if not hasattr(thread_local, "sb"):
        thread_local.sb = statbotics.Statbotics()
    return thread_local.sb


def fetch_team_event_epa(team_num, event_key):
    last_error = None
    for attempt in range(MAX_RETRIES):
        try:
            sb = get_client()
            epa = sb.get_team_event(team=team_num, event=event_key, fields=["epa"]).get("epa", {})
            breakdown = epa.get("breakdown", {})
            return {
                "unitless": epa.get("unitless"),
                "norm": epa.get("norm"),
                "rp_1": breakdown.get("rp_1"),
                "rp_2": breakdown.get("rp_2"),
            }
        except Exception as e:
            last_error = e
            if attempt < MAX_RETRIES - 1:
                time.sleep(BACKOFF_SECONDS * (2 ** attempt))

    return {
        "unitless": pd.NA,
        "norm": pd.NA,
        "rp_1": pd.NA,
        "rp_2": pd.NA,
        "error": str(last_error),
    }


results_cache = {}
errors = []
request_list = list(unique_requests)

if request_list:
    max_workers = min(MAX_WORKERS, len(request_list))
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_req = {
            executor.submit(fetch_team_event_epa, team_num, event_key): (team_num, event_key)
            for team_num, event_key in request_list
        }

        for i, future in enumerate(as_completed(future_to_req), start=1):
            team_num, event_key = future_to_req[future]
            result = future.result()
            results_cache[(team_num, event_key)] = result

            if "error" in result:
                errors.append((team_num, event_key, result["error"]))

            if i % 100 == 0 or i == len(request_list):
                print(f"Fetched {i}/{len(request_list)} unique team/event records")

# Write cached results back to every matching row/column target.
for row_idx, col, team_num, event_key in tasks:
    result = results_cache.get((team_num, event_key))
    if not result:
        continue

    df.at[row_idx, f"{col}_epa"] = result["unitless"]
    df.at[row_idx, f"{col}_epa_norm"] = result["norm"]
    df.at[row_idx, f"{col}_rp_1"] = result["rp_1"]
    df.at[row_idx, f"{col}_rp_2"] = result["rp_2"]

df.to_csv(OUTPUT_CSV, index=False)
print(f"Modified data written to {OUTPUT_CSV}")
print(f"Failed fetches after retries: {len(errors)}")
if errors:
    print("First 10 errors:")
    for team_num, event_key, err in errors[:10]:
        print(f"  team {team_num}, event {event_key}: {err}")
# Out:
# /tmp/ipykernel_454565/1444421291.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_rp_1"] = pd.NA
# /tmp/ipykernel_454565/1444421291.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_rp_2"] = pd.NA
# /tmp/ipykernel_454565/1444421291.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_epa"] = pd.NA
# /tmp/ipykernel_454565/1444421291.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{col}_epa_norm"] = pd.NA
# Rows: 782
# Team assignments to fill: 18504
# Unique API requests: 18504
# Fetched 100/18504 unique team/event records
# Fetched 200/18504 unique team/event records
# Fetched 300/18504 unique team/event records
# Fetched 400/18504 unique team/event records
# Fetched 500/18504 unique team/event records
# Fetched 600/18504 unique team/event records
# Fetched 700/18504 unique team/event records
# Fetched 800/18504 unique team/event records
# Fetched 900/18504 unique team/event records
# Fetched 1000/18504 unique team/event records
# Fetched 1100/18504 unique team/event records
# Fetched 1200/18504 unique team/event records
# Fetched 1300/18504 unique team/event records
# Fetched 1400/18504 unique team/event records
# Fetched 1500/18504 unique team/event records
# Fetched 1600/18504 unique team/event records
# Fetched 1700/18504 unique team/event records
# Fetched 1800/18504 unique team/event records
# Fetched 1900/18504 unique team/event records
# Fetched 2000/18504 unique team/event records
# Fetched 2100/18504 unique team/event records
# Fetched 2200/18504 unique team/event records
# Fetched 2300/18504 unique team/event records
# Fetched 2400/18504 unique team/event records
# Fetched 2500/18504 unique team/event records
# Fetched 2600/18504 unique team/event records
# Fetched 2700/18504 unique team/event records
# Fetched 2800/18504 unique team/event records
# Fetched 2900/18504 unique team/event records
# Fetched 3000/18504 unique team/event records
# Fetched 3100/18504 unique team/event records
# Fetched 3200/18504 unique team/event records
# Fetched 3300/18504 unique team/event records
# Fetched 3400/18504 unique team/event records
# Fetched 3500/18504 unique team/event records
# Fetched 3600/18504 unique team/event records
# Fetched 3700/18504 unique team/event records
# Fetched 3800/18504 unique team/event records
# Fetched 3900/18504 unique team/event records
# Fetched 4000/18504 unique team/event records
# Fetched 4100/18504 unique team/event records
# Fetched 4200/18504 unique team/event records
# Fetched 4300/18504 unique team/event records
# Fetched 4400/18504 unique team/event records
# Fetched 4500/18504 unique team/event records
# Fetched 4600/18504 unique team/event records
# Fetched 4700/18504 unique team/event records
# Fetched 4800/18504 unique team/event records
# Fetched 4900/18504 unique team/event records
# Fetched 5000/18504 unique team/event records
# Fetched 5100/18504 unique team/event records
# Fetched 5200/18504 unique team/event records
# Fetched 5300/18504 unique team/event records
# Fetched 5400/18504 unique team/event records
# Fetched 5500/18504 unique team/event records
# Fetched 5600/18504 unique team/event records
# Fetched 5700/18504 unique team/event records
# Fetched 5800/18504 unique team/event records
# Fetched 5900/18504 unique team/event records
# Fetched 6000/18504 unique team/event records
# Fetched 6100/18504 unique team/event records
# Fetched 6200/18504 unique team/event records
# Fetched 6300/18504 unique team/event records
# Fetched 6400/18504 unique team/event records
# Fetched 6500/18504 unique team/event records
# Fetched 6600/18504 unique team/event records
# Fetched 6700/18504 unique team/event records
# Fetched 6800/18504 unique team/event records
# Fetched 6900/18504 unique team/event records
# Fetched 7000/18504 unique team/event records
# Fetched 7100/18504 unique team/event records
# Fetched 7200/18504 unique team/event records
# Fetched 7300/18504 unique team/event records
# Fetched 7400/18504 unique team/event records
# Fetched 7500/18504 unique team/event records
# Fetched 7600/18504 unique team/event records
# Fetched 7700/18504 unique team/event records
# Fetched 7800/18504 unique team/event records
# Fetched 7900/18504 unique team/event records
# Fetched 8000/18504 unique team/event records
# Fetched 8100/18504 unique team/event records
# Fetched 8200/18504 unique team/event records
# Fetched 8300/18504 unique team/event records
# Fetched 8400/18504 unique team/event records
# Fetched 8500/18504 unique team/event records
# Fetched 8600/18504 unique team/event records
# Fetched 8700/18504 unique team/event records
# Fetched 8800/18504 unique team/event records
# Fetched 8900/18504 unique team/event records
# Fetched 9000/18504 unique team/event records
# Fetched 9100/18504 unique team/event records
# Fetched 9200/18504 unique team/event records
# Fetched 9300/18504 unique team/event records
# Fetched 9400/18504 unique team/event records
# Fetched 9500/18504 unique team/event records
# Fetched 9600/18504 unique team/event records
# Fetched 9700/18504 unique team/event records
# Fetched 9800/18504 unique team/event records
# Fetched 9900/18504 unique team/event records
# Fetched 10000/18504 unique team/event records
# Fetched 10100/18504 unique team/event records
# Fetched 10200/18504 unique team/event records
# Fetched 10300/18504 unique team/event records
# Fetched 10400/18504 unique team/event records
# Fetched 10500/18504 unique team/event records
# Fetched 10600/18504 unique team/event records
# Fetched 10700/18504 unique team/event records
# Fetched 10800/18504 unique team/event records
# Fetched 10900/18504 unique team/event records
# Fetched 11000/18504 unique team/event records
# Fetched 11100/18504 unique team/event records
# Fetched 11200/18504 unique team/event records
# Fetched 11300/18504 unique team/event records
# Fetched 11400/18504 unique team/event records
# Fetched 11500/18504 unique team/event records
# Fetched 11600/18504 unique team/event records
# Fetched 11700/18504 unique team/event records
# Fetched 11800/18504 unique team/event records
# Fetched 11900/18504 unique team/event records
# Fetched 12000/18504 unique team/event records
# Fetched 12100/18504 unique team/event records
# Fetched 12200/18504 unique team/event records
# Fetched 12300/18504 unique team/event records
# Fetched 12400/18504 unique team/event records
# Fetched 12500/18504 unique team/event records
# Fetched 12600/18504 unique team/event records
# Fetched 12700/18504 unique team/event records
# Fetched 12800/18504 unique team/event records
# Fetched 12900/18504 unique team/event records
# Fetched 13000/18504 unique team/event records
# Fetched 13100/18504 unique team/event records
# Fetched 13200/18504 unique team/event records
# Fetched 13300/18504 unique team/event records
# Fetched 13400/18504 unique team/event records
# Fetched 13500/18504 unique team/event records
# Fetched 13600/18504 unique team/event records
# Fetched 13700/18504 unique team/event records
# Fetched 13800/18504 unique team/event records
# Fetched 13900/18504 unique team/event records
# Fetched 14000/18504 unique team/event records
# Fetched 14100/18504 unique team/event records
# Fetched 14200/18504 unique team/event records
# Fetched 14300/18504 unique team/event records
# Fetched 14400/18504 unique team/event records
# Fetched 14500/18504 unique team/event records
# Fetched 14600/18504 unique team/event records
# Fetched 14700/18504 unique team/event records
# Fetched 14800/18504 unique team/event records
# Fetched 14900/18504 unique team/event records
# Fetched 15000/18504 unique team/event records
# Fetched 15100/18504 unique team/event records
# Fetched 15200/18504 unique team/event records
# Fetched 15300/18504 unique team/event records
# Fetched 15400/18504 unique team/event records
# Fetched 15500/18504 unique team/event records
# Fetched 15600/18504 unique team/event records
# Fetched 15700/18504 unique team/event records
# Fetched 15800/18504 unique team/event records
# Fetched 15900/18504 unique team/event records
# Fetched 16000/18504 unique team/event records
# Fetched 16100/18504 unique team/event records
# Fetched 16200/18504 unique team/event records
# Fetched 16300/18504 unique team/event records
# Fetched 16400/18504 unique team/event records
# Fetched 16500/18504 unique team/event records
# Fetched 16600/18504 unique team/event records
# Fetched 16700/18504 unique team/event records
# Fetched 16800/18504 unique team/event records
# Fetched 16900/18504 unique team/event records
# Fetched 17000/18504 unique team/event records
# Fetched 17100/18504 unique team/event records
# Fetched 17200/18504 unique team/event records
# Fetched 17300/18504 unique team/event records
# Fetched 17400/18504 unique team/event records
# Fetched 17500/18504 unique team/event records
# Fetched 17600/18504 unique team/event records
# Fetched 17700/18504 unique team/event records
# Fetched 17800/18504 unique team/event records
# Fetched 17900/18504 unique team/event records
# Fetched 18000/18504 unique team/event records
# Fetched 18100/18504 unique team/event records
# Fetched 18200/18504 unique team/event records
# Fetched 18300/18504 unique team/event records
# Fetched 18400/18504 unique team/event records
# Fetched 18500/18504 unique team/event records
# Fetched 18504/18504 unique team/event records
# Modified data written to playoff_alliances_with_team_statbotics.csv
# Failed fetches after retries: 79
# First 10 errors:
#   team 1153, event 2025week0: Invalid query: /team_event/1153/2025week0
#   team 157, event 2023week0: Invalid query: /team_event/157/2023week0
#   team 5687, event 2025week0: Invalid query: /team_event/5687/2025week0
#   team 151, event 2023week0: Invalid query: /team_event/151/2023week0
#   team 1058, event 2024week0: Invalid query: /team_event/1058/2024week0
#   team 4909, event 2023week0: Invalid query: /team_event/4909/2023week0
#   team 166, event 2023week0: Invalid query: /team_event/166/2023week0
#   team 509, event 2024week0: Invalid query: /team_event/509/2024week0
#   team 2342, event 2023week0: Invalid query: /team_event/2342/2023week0
#   team 4909, event 2024week0: Invalid query: /team_event/4909/2024week0

# %%
# Load enriched data and drop all week0 events

enriched_df = pd.read_csv(OUTPUT_CSV)
print(f"Enriched data loaded with {len(enriched_df)} rows before dropping week0 events")
enriched_df = enriched_df[~enriched_df["event_key"].str.contains("week0", case=False, na=False)].reset_index(drop=True)
print(f"Enriched data loaded with {len(enriched_df)} rows after dropping week0 events")
df.to_csv(OUTPUT_CSV, index=False)
# Out:
# Enriched data loaded with 782 rows before dropping week0 events
# Enriched data loaded with 778 rows after dropping week0 events
